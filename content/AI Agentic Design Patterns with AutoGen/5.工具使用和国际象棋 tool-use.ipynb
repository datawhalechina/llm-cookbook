# %% [markdown]
# # 5.工具使用和国际象棋

# %% [markdown]
# ## 基础配置

# %%
from utils import get_openai_api_key, get_openai_base_url
OPENAI_API_KEY = get_openai_api_key()
OPENAI_BASE_URL = get_openai_base_url()
llm_config = {"model": "gpt-4o"}

# %%
import chess
import chess.svg
from typing_extensions import Annotated

# %% [markdown]
# ## 初始化国际象棋棋盘

# %%
board = chess.Board()

# %%
made_move = False

# %% [markdown]
# ## 定义需要的工具
#
# ### 1. 获取合规行动的工具

# %%
def get_legal_moves(
    
) -> Annotated[str, "A list of legal moves in UCI format"]:
    return "Possible moves are: " + ",".join(
        [str(move) for move in board.legal_moves]
    )

# %% [markdown]
# ### 2. 在棋盘上行动一步的工具

# %%
def make_move(
    move: Annotated[str, "A move in UCI format."]
) -> Annotated[str, "Result of the move."]:
    move = chess.Move.from_uci(move)
    board.push_uci(str(move))
    global made_move
    made_move = True
    
    # 可视化棋盘
    display(
        chess.svg.board(
            board,
            arrows=[(move.from_square, move.to_square)],
            fill={move.from_square: "gray"},
            size=200
        )
    )
    
    # 获取棋子的名称
    piece = board.piece_at(move.to_square)
    piece_symbol = piece.unicode_symbol()
    piece_name = (
        chess.piece_name(piece.piece_type).capitalize()
        if piece_symbol.isupper()
        else chess.piece_name(piece.piece_type)
    )
    return f"Moved {piece_name} ({piece_symbol}) from "\
    f"{chess.SQUARE_NAMES[move.from_square]} to "\
    f"{chess.SQUARE_NAMES[move.to_square]}."

# %% [markdown]
# `UCI`, 即`Universal Chess Interface`格式是国际象棋引擎与界面之间进行通信的标准化协议。</br>
# 它由`Chess Engine Communication Protocol,CECP`发展而来，并被广泛用于现代国际象棋软件中。</br>
# 使用UCI格式可以确保不同国际象棋程序间的兼容性和互操作性。
#
# `UCI`格式的主要用途包括：
#
# 1. **走子描述**：提供一种标准的方式来表示棋盘上的位置和棋子的移动。例如，`e2e4`表示从位置`e2`到`e4`的移动。
#
# 2. **命令接口**：允许用户或程序与棋弈引擎进行交互，如搜索选项设置、局面分析等。
#
# 3. **棋局导入/导出**：支持将棋局保存为文本格式，方便在不同的程序间传输。
#
# 在上述代码中，`chess.Move.from_uci(move)`函数用于将`UCI`格式的字符串转换为一个内部表示的`Move`对象。这种转换使得程序能够理解用户的走子意图，并在棋盘上执行相应的操作。

# %% [markdown]
# ## 创建智能体
#
# 接下来，我们将在棋盘上创建两个玩家智能体和一个象棋裁判智能体。

# %%
from autogen import ConversableAgent

# %%
# 白色方智能体
player_white = ConversableAgent(
    name="Player White",
    system_message="You are a chess player and you play as white. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move.",
    llm_config=llm_config,
)

# %%
# 黑色方智能体
player_black = ConversableAgent(
    name="Player Black",
    system_message="You are a chess player and you play as black. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move.",
    llm_config=llm_config,
)

# %%
def check_made_move(msg):
    global made_move
    if made_move:
        made_move = False
        return True
    else:
        return False

# %%
board_proxy = ConversableAgent(
    name="Board Proxy",
    llm_config=False,
    is_termination_msg=check_made_move,
    default_auto_reply="Please make a move.",
    human_input_mode="NEVER",
)

# %% [markdown]
# ## 注册工具
#
# 工具需要被注册后才能被智能体调用或执行

# %%
from autogen import register_function

# %%
for caller in [player_white, player_black]:
    register_function(
        get_legal_moves,
        caller=caller,
        executor=board_proxy,
        name="get_legal_moves",
        description="Get legal moves.",
    )
    
    register_function(
        make_move,
        caller=caller,
        executor=board_proxy,
        name="make_move",
        description="Call this tool to make a move.",
    )

# %%
player_black.llm_config["tools"]
# Out:
# [{'type': 'function',
#   'function': {'description': 'Get legal moves.',
#    'name': 'get_legal_moves',
#    'parameters': {'type': 'object', 'properties': {}, 'required': []}}},
#  {'type': 'function',
#   'function': {'description': 'Call this tool to make a move.',
#    'name': 'make_move',
#    'parameters': {'type': 'object',
#     'properties': {'move': {'type': 'string',
#       'description': 'A move in UCI format.'}},
#     'required': ['move']}}}]

# %% [markdown]
# ## 嵌套交互注册
#
# 每个玩家智能体都将与象棋裁判智能体进行嵌套交互，从而在棋盘上执行移动。

# %%
player_white.register_nested_chats(
    trigger=player_black,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_white,
            "summary_method": "last_msg",
        }
    ],
)

player_black.register_nested_chats(
    trigger=player_white,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_black,
            "summary_method": "last_msg",
        }
    ],
)

# %% [markdown]
# ## 开始游戏
#
# 游戏将从第一条消息开始。

# %% [markdown]
# <p style="background-color:#ECECEC; padding:15px; "> <b>注意1：</b>对于本课程的代码实践，推荐使用gpt-4-turbo或gpt-4o来获得更好的结果。</br><b>注意2：</b>每次实验结果的玩家的棋子移动都可能略有不同。因为这和大语言模型的底层逻辑，预测下一个生成token的最大概率有关。</p>

# %%
board = chess.Board()

chat_result = player_black.initiate_chat(
    player_white,
    message="Let's play chess! Your move.",
    max_turns=2,
)
# Out:
# Player Black (to Player White):
#
# Let's play chess! Your move.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Board Proxy (to Player White):
#
# Let's play chess! Your move.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# Player White (to Board Proxy):
#
# ***** Suggested tool call (call_KrerPlbKm6AvUnVKyC11H0Uw): get_legal_moves *****
# Arguments:
# {}
# ********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_legal_moves...
# Board Proxy (to Player White):
#
# Board Proxy (to Player White):
#
# ...

# %% [markdown]
# ## 为游戏过程添加一些有趣的闲聊

# %%
player_white = ConversableAgent(
    name="Player White",
    system_message="You are a chess player and you play as white. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move. "
    "After a move is made, chitchat to make the game fun.",
    llm_config=llm_config,
)

# %%
player_black = ConversableAgent(
    name="Player Black",
    system_message="You are a chess player and you play as black. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move. "
    "After a move is made, chitchat to make the game fun.",
    llm_config=llm_config,
)

# %%
for caller in [player_white, player_black]:
    register_function(
        get_legal_moves,
        caller=caller,
        executor=board_proxy,
        name="get_legal_moves",
        description="Get legal moves.",
    )

    register_function(
        make_move,
        caller=caller,
        executor=board_proxy,
        name="make_move",
        description="Call this tool to make a move.",
    )

player_white.register_nested_chats(
    trigger=player_black,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_white,
            "summary_method": "last_msg",
            "silent": True,
        }
    ],
)

player_black.register_nested_chats(
    trigger=player_white,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_black,
            "summary_method": "last_msg",
            "silent": True,
        }
    ],
)

# %%
board = chess.Board()

chat_result = player_black.initiate_chat(
    player_white,
    message="Let's play chess! Your move.",
    max_turns=2,
)
# Out:
# Player Black (to Player White):
#
# Let's play chess! Your move.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION get_legal_moves...
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION make_move...
# ...

# %% [markdown]
# **注意：**
# 如果要为游戏添加人为输入，请为两个玩家智能体添加参数 **`human_input_mode="ALWAYS"`**。
